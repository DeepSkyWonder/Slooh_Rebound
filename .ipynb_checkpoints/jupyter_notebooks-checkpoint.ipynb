# %% [markdown]
# ## Rebound Inner Solar System plus Eccentric Planet Simulation

# %%
import rebound

# %%
import numpy as np

# %%
# Create simulation
sim = rebound.Simulation()

# %%
# Set initial value of G
sim.G = 6.6743e-11 # m^3 / kg s^2 for time (s), mass (kg), distance (m)

# %%
# Set simulation units
sim.units = ['AU','yr','Msun']

# G is automatically adjusted to match these units
print("G = {0}.".format(sim.G))
# Out:
# G = 39.476926421373.

# %%
# Add the Sun from JPL Horizons. This will take a few moments.
sim.add('Sun')
# Out:
# Searching NASA Horizons for 'Sun'... Found: Target body name: Sun (10).

# %%
# Add Mercury from JPL Horizons
sim.add('Mercury')
# Out:
# Searching NASA Horizons for 'Mercury'... Found: Target body name: Mercury Barycenter (199).

# %%
# Add Venus from JPL Horizons
sim.add('Venus')
# Out:
# Searching NASA Horizons for 'Venus'... Found: Target body name: Venus Barycenter (299).

# %%
# Add Earth from JPL Horizons
sim.add('Earth')
# Out:
# Searching NASA Horizons for 'Earth'... Found: Target body name: Earth-Moon Barycenter (3).

# %%
# Add Mars from JPL Horizons
sim.add('Mars')
# Out:
# Searching NASA Horizons for 'Mars'... Found: Target body name: Mars Barycenter (4).

# %%
# Add our Eccentric orbit planet
sim.add(a=1.5, e=0.4)

# %%
# Current Simulation Time. Should be 0.0 years
sim.t
# Out:
# 0.0

# %%
# Get the current time. This will be the simulation start time.
from astropy.time import Time
nt = Time.now()
nt.format = 'decimalyear'
time_now = nt.value
time_now
# Out:
# 2021.5756313446946

# %%
import imageio
import os

# %%
filenames = []

from IPython.display import display, clear_output
import matplotlib.pyplot as plt

# Move to the centre of mass of the system
sim.move_to_com()

# Simulation
for i in range(60):
    
    # Timestep
    sim.integrate(sim.t+0.03)
    
    # Plot orbits. Use the 'fancy' option with stars and a glowing star.
    fig, ax1, ax2, ax3 = rebound.OrbitPlot(sim, figsize=(15,13), slices=0.5, unitlabel='[AU]', color = ['lightsteelblue', 'orange', 'dodgerblue', 'chocolate', 'limegreen'], lw=2, fancy=True, xlim=[-2.6,2.6], ylim=[-2.6,2.6])
    
    # Calculate current time in years
    current_time = Time(str(time_now + round(sim.t,2)), format='decimalyear')
    
    # Display current time
    ax2.text(-2.1, 0.6, 'Time: ' + str(round(current_time.value,2)), color='white', fontsize=13)
    
    display(fig)    
    
    # Create file name and append it to a list
    filename = f'{i}.png'
    filenames.append('/Users/cmcewing/Astronomy/Slooh/00 - Animations/rebound/' + filename)
    
    # Save frame to directory
    plt.savefig('/Users/cmcewing/Astronomy/Slooh/00 - Animations/rebound/' + filename, dpi=96)
    plt.close()
    clear_output(wait=True)


# Build GIF
with imageio.get_writer('/Users/cmcewing/Astronomy/Slooh/00 - Animations/rebound/rebound-inner-solar-system.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
        
# Remove temporary files containing animation frame images

for filename in set(filenames):
    os.remove(filename)
